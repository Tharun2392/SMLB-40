# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharun2392/SMLB-40/blob/main/SML_ASSIGNMENT_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# J.Tharun(2303A52386)
#
# BATCH 40

# %% [markdown]
# Question 1:From the above data:
#
# Read the data with pandas and find features and target variables
# Plot a graph between features and target
# Find Best fit line using linear regression.
# FInd MSE, MAE, for test size (20,25)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_csv('/content/Salary_Data.csv')

X = df[['YearsExperience']]
y = df['Salary']

plt.scatter(X, y, color='blue', label='Experience vs Salary')
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

for test_size in [0.20, 0.25]:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test Size: {int(test_size*100)}%")
    print(f"MSE: {mse}")
    print(f"MAE: {mae}\n")

    plt.scatter(X_test, y_test, color='blue', label='Test Data')
    plt.plot(X_test, y_pred, color='red', label='Best Fit Line')
    plt.title(f'Linear Regression with Test Size {int(test_size*100)}%')
    plt.xlabel('Years of Experience')
    plt.ylabel('Salary')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Test Size: 20%
# MSE: 49830096.85590839
# MAE: 6286.453830757749
# Test Size: 25%
# MSE: 38802588.99247065
# MAE: 5056.995466663592

# %% [markdown]
# Questions 2:
#
# Read the data with pandas and find features and target variables
# Plot a graph between features and target
# Find Best fit line using linear regression.
# Fond MSE , MAE for test size (20,30)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

data = {
    'Feature1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4.0],
    'Feature2': [2.3, 1.9, 2.7, 3.0, 2.8, 2.5, 3.2, 2.4, 3.1, 3.3],
    'Feature3': [3.1, 2.8, 1.5, 3.6, 2.5, 1.9, 2.2, 3.0, 1.8, 2.7],
    'Feature4': [4.2, 3.5, 2.9, 4.8, 3.2, 4.0, 4.1, 4.5, 3.6, 4.9],
    'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16.0, 14.5, 17.3, 14.9, 19.2]
}

df = pd.DataFrame(data)

X = df[['Feature1', 'Feature2', 'Feature3', 'Feature4']]
y = df['Target']

plt.scatter(df['Feature1'], df['Target'], color='blue', label='Feature 1 vs Target')
plt.title('Feature 1 vs Target')
plt.xlabel('Feature 1')
plt.ylabel('Target (Y)')
plt.legend()
plt.grid(True)
plt.show()

for test_size in [0.20, 0.30]:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test Size: {int(test_size*100)}%")
    print(f"MSE: {mse}")
    print(f"MAE: {mae}\n")

    plt.scatter(X_test['Feature1'], y_test, color='blue', label='Test Data')
    plt.plot(X_test['Feature1'], y_pred, color='red', label='Best Fit Line')
    plt.title(f'Linear Regression with Test Size {int(test_size*100)}%')
    plt.xlabel('Feature 1')
    plt.ylabel('Target (Y)')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Test Size: 20%
# MSE: 1.2020186561889346
# MAE: 1.0313248712002014
# Test Size: 30%
# MSE: 0.8283376869765737
# MAE: 0.8651731636820733

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Step 1: Read the data
data = pd.read_csv('/content/Salary_Data.csv')
# Step 2: Define feature and target variables
X = data[['YearsExperience']] # Changed 'Feature 1' to 'YearsExperience'
y = data['Salary'] # Changed 'Target (Y)' to 'Salary'
print(data)
# Display the first few rows to understand its structure
data.head()
# Step 3: Create a linear regression model and fit it
model = LinearRegression()
model.fit(X, y)
# Step 4: Predict values using the model (best fit line)
y_pred = model.predict(X)
# Step 5: Plot the graph between the feature and target
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Best fit line')
plt.title('YearsExperience vs Salary') # Changed title to reflect the correct column names
plt.xlabel('YearsExperience') # Changed x-axis label
plt.ylabel('Salary') # Changed y-axis label
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
